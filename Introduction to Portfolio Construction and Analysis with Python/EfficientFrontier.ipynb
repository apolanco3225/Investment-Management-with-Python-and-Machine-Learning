# %% [markdown]
# ## Efficient Frontier

# %%
import pandas as pd
# %load_ext autoreload
# %autoreload 2
import edhec_risk_kit as erk

# %%
ind = pd.read_csv(
    "data/ind30_m_vw_rets.csv", 
    index_col=0, 
    parse_dates = True
) / 100
ind.head()
# Out:
#          Food    Beer    Smoke   Games   Books   Hshld   Clths   Hlth   \
# 192607  0.0056 -0.0519  0.0129  0.0293  0.1097 -0.0048  0.0808  0.0177
# 192608  0.0259  0.2703  0.0650  0.0055  0.1001 -0.0358 -0.0251  0.0425
# 192609  0.0116  0.0402  0.0126  0.0658 -0.0099  0.0073 -0.0051  0.0069
# 192610 -0.0306 -0.0331  0.0106 -0.0476  0.0947 -0.0468  0.0012 -0.0057
# 192611  0.0635  0.0729  0.0455  0.0166 -0.0580 -0.0054  0.0187  0.0542
#
#          Chems   Txtls  ...   Telcm   Servs   BusEq   Paper   Trans   Whlsl  \
# 192607  0.0814  0.0039  ...  0.0083  0.0922  0.0206  0.0770  0.0193 -0.2379
# 192608  0.0550  0.0814  ...  0.0217  0.0202  0.0439 -0.0238  0.0488  0.0539
# 192609  0.0533  0.0231  ...  0.0241  0.0225  0.0019 -0.0554  0.0005 -0.0787
# 192610 -0.0476  0.0100  ... -0.0011 -0.0200 -0.0109 -0.0508 -0.0264 -0.1538
# 192611  0.0520  0.0311  ...  0.0163  0.0377  0.0364  0.0384  0.0160  0.0467
#
#          Rtail   Meals   Fin     Other
# 192607  0.0007  0.0187  0.0037  0.0520
# 192608 -0.0075 -0.0013  0.0446  0.0676
# 192609  0.0025 -0.0056 -0.0123 -0.0386
# 192610 -0.0220 -0.0411 -0.0516 -0.0849
# 192611  0.0652  0.0433  0.0224  0.0400
#
# [5 rows x 30 columns]

# %%
ind.index
# Out:
# Int64Index([192607, 192608, 192609, 192610, 192611, 192612, 192701, 192702,
#             192703, 192704,
#             ...
#             201803, 201804, 201805, 201806, 201807, 201808, 201809, 201810,
#             201811, 201812],
#            dtype='int64', length=1110)

# %%
ind.index = pd.to_datetime(ind.index, format="%Y%m").to_period("M")
ind.index
# Out:
# PeriodIndex(['1926-07', '1926-08', '1926-09', '1926-10', '1926-11', '1926-12',
#              '1927-01', '1927-02', '1927-03', '1927-04',
#              ...
#              '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08',
#              '2018-09', '2018-10', '2018-11', '2018-12'],
#             dtype='period[M]', length=1110)

# %%
ind.head()
# Out:
#           Food    Beer    Smoke   Games   Books   Hshld   Clths   Hlth   \
# 1926-07  0.0056 -0.0519  0.0129  0.0293  0.1097 -0.0048  0.0808  0.0177
# 1926-08  0.0259  0.2703  0.0650  0.0055  0.1001 -0.0358 -0.0251  0.0425
# 1926-09  0.0116  0.0402  0.0126  0.0658 -0.0099  0.0073 -0.0051  0.0069
# 1926-10 -0.0306 -0.0331  0.0106 -0.0476  0.0947 -0.0468  0.0012 -0.0057
# 1926-11  0.0635  0.0729  0.0455  0.0166 -0.0580 -0.0054  0.0187  0.0542
#
#           Chems   Txtls  ...   Telcm   Servs   BusEq   Paper   Trans   Whlsl  \
# 1926-07  0.0814  0.0039  ...  0.0083  0.0922  0.0206  0.0770  0.0193 -0.2379
# 1926-08  0.0550  0.0814  ...  0.0217  0.0202  0.0439 -0.0238  0.0488  0.0539
# 1926-09  0.0533  0.0231  ...  0.0241  0.0225  0.0019 -0.0554  0.0005 -0.0787
# 1926-10 -0.0476  0.0100  ... -0.0011 -0.0200 -0.0109 -0.0508 -0.0264 -0.1538
# 1926-11  0.0520  0.0311  ...  0.0163  0.0377  0.0364  0.0384  0.0160  0.0467
#
#           Rtail   Meals   Fin     Other
# 1926-07  0.0007  0.0187  0.0037  0.0520
# 1926-08 -0.0075 -0.0013  0.0446  0.0676
# 1926-09  0.0025 -0.0056 -0.0123 -0.0386
# 1926-10 -0.0220 -0.0411 -0.0516 -0.0849
# 1926-11  0.0652  0.0433  0.0224  0.0400
#
# [5 rows x 30 columns]

# %%
ind.columns = ind.columns.str.strip()

# %%
ind.columns = ind.columns.str.lower()

# %%
ind.columns
# Out:
# Index(['food', 'beer', 'smoke', 'games', 'books', 'hshld', 'clths', 'hlth',
#        'chems', 'txtls', 'cnstr', 'steel', 'fabpr', 'elceq', 'autos', 'carry',
#        'mines', 'coal', 'oil', 'util', 'telcm', 'servs', 'buseq', 'paper',
#        'trans', 'whlsl', 'rtail', 'meals', 'fin', 'other'],
#       dtype='object')

# %%
ind = erk.get_ind_returns()
ind.head()
# Out:
#            food    beer   smoke   games   books   hshld   clths    hlth  \
# 1926-07  0.0056 -0.0519  0.0129  0.0293  0.1097 -0.0048  0.0808  0.0177
# 1926-08  0.0259  0.2703  0.0650  0.0055  0.1001 -0.0358 -0.0251  0.0425
# 1926-09  0.0116  0.0402  0.0126  0.0658 -0.0099  0.0073 -0.0051  0.0069
# 1926-10 -0.0306 -0.0331  0.0106 -0.0476  0.0947 -0.0468  0.0012 -0.0057
# 1926-11  0.0635  0.0729  0.0455  0.0166 -0.0580 -0.0054  0.0187  0.0542
#
#           chems   txtls  ...   telcm   servs   buseq   paper   trans   whlsl  \
# 1926-07  0.0814  0.0039  ...  0.0083  0.0922  0.0206  0.0770  0.0193 -0.2379
# 1926-08  0.0550  0.0814  ...  0.0217  0.0202  0.0439 -0.0238  0.0488  0.0539
# 1926-09  0.0533  0.0231  ...  0.0241  0.0225  0.0019 -0.0554  0.0005 -0.0787
# 1926-10 -0.0476  0.0100  ... -0.0011 -0.0200 -0.0109 -0.0508 -0.0264 -0.1538
# 1926-11  0.0520  0.0311  ...  0.0163  0.0377  0.0364  0.0384  0.0160  0.0467
#
#           rtail   meals     fin   other
# 1926-07  0.0007  0.0187  0.0037  0.0520
# 1926-08 -0.0075 -0.0013  0.0446  0.0676
# 1926-09  0.0025 -0.0056 -0.0123 -0.0386
# 1926-10 -0.0220 -0.0411 -0.0516 -0.0849
# 1926-11  0.0652  0.0433  0.0224  0.0400
#
# [5 rows x 30 columns]

# %%
erk.calculate_drawdown(ind.food)["drawdown"].plot(figsize=(12, 6));

# %%
cols_of_interest = ["food", "smoke", "coal", "beer", "fin"]
erk.var_gaussian(ind[cols_of_interest], modified=True)
# Out:
# food     0.061207
# smoke    0.080292
# coal     0.047359
# beer     0.033881
# fin      0.075199
# dtype: float64

# %%
erk.var_gaussian(
    ind, modified=True
).sort_values().head().plot.barh()
# Out:
# <AxesSubplot:>

# %%
erk.var_gaussian(
    ind, modified=True
).sort_values().tail().plot.barh()
# Out:
# <AxesSubplot:>

# %%
erk.var_gaussian(
    ind, modified=True
).sort_values().plot.bar()
# Out:
# <AxesSubplot:>

# %%
erk.sharpe_ratio(
    ind.loc["2000":], 
    risk_free_rate = 0.03, 
    periods_per_year=12
).sort_values().plot.bar(
    title="Industry Sharpe Ratio 2000-2018", 
    color="goldenrod", 
    figsize=(12, 6)
);

# %%
er = erk.annualize_rets(
    ind.loc["1995":"2000"], 
    12
)
er.sort_values().plot.bar(grid=True);

# %%
cov = ind.loc["1995":"2000"].cov()
print(cov.shape)
# Out:
# (30, 30)

# %%
import matplotlib.pyplot as plt

# %%
cov.style.background_gradient(cmap ="BrBG")
# Out:
# <style type="text/css">
# #T_0f03f_row0_col0, #T_0f03f_row1_col1, #T_0f03f_row2_col2, #T_0f03f_row3_col3, #T_0f03f_row4_col4, #T_0f03f_row5_col5, #T_0f03f_row6_col6, #T_0f03f_row7_col7, #T_0f03f_row8_col8, #T_0f03f_row9_col9, #T_0f03f_row10_col10, #T_0f03f_row11_col11, #T_0f03f_row12_col12, #T_0f03f_row13_col13, #T_0f03f_row14_col14, #T_0f03f_row15_col15, #T_0f03f_row16_col16, #T_0f03f_row17_col17, #T_0f03f_row18_col18, #T_0f03f_row19_col19, #T_0f03f_row20_col20, #T_0f03f_row21_col21, #T_0f03f_row22_col22, #T_0f03f_row23_col23, #T_0f03f_row24_col24, #T_0f03f_row25_col25, #T_0f03f_row26_col26, #T_0f03f_row27_col27, #T_0f03f_row28_col28, #T_0f03f_row29_col29 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_0f03f_row0_col1, #T_0f03f_row0_col24, #T_0f03f_row2_col25, #T_0f03f_row4_col8, #T_0f03f_row5_col7, #T_0f03f_row8_col6, #T_0f03f_row13_col8, #T_0f03f_row14_col5 {
#   background-color: #f6eedb;
#   color: #000000;
# }
# #T_0f03f_row0_col2, #T_0f03f_row1_col14, #T_0f03f_row9_col18, #T_0f03f_row15_col11, #T_0f03f_row21_col23, #T_0f03f_row23_col29 {
#   background-color: #dec17b;
#   color: #000000;
# }
# #T_0f03f_row0_col3, #T_0f03f_row4_col5, #T_0f03f_row17_col26, #T_0f03f_row20_col1, #T_0f03f_row23_col2, #T_0f03f_row24_col16 {
#   background-color: #c28633;
#   color: #f1f1f1;
# }
# #T_0f03f_row0_col4, #T_0f03f_row22_col24 {
#   background-color: #f6eac9;
#   color: #000000;
# }
# #T_0f03f_row0_col5, #T_0f03f_row9_col6, #T_0f03f_row15_col13, #T_0f03f_row16_col22, #T_0f03f_row17_col13, #T_0f03f_row25_col22 {
#   background-color: #e8d29a;
#   color: #000000;
# }
# #T_0f03f_row0_col6, #T_0f03f_row2_col18, #T_0f03f_row22_col15, #T_0f03f_row26_col16 {
#   background-color: #bb7d2a;
#   color: #f1f1f1;
# }
# #T_0f03f_row0_col7, #T_0f03f_row3_col19, #T_0f03f_row4_col21, #T_0f03f_row7_col1, #T_0f03f_row8_col11, #T_0f03f_row12_col16, #T_0f03f_row16_col7, #T_0f03f_row20_col14, #T_0f03f_row25_col14 {
#   background-color: #eedbaa;
#   color: #000000;
# }
# #T_0f03f_row0_col8, #T_0f03f_row3_col9, #T_0f03f_row14_col0, #T_0f03f_row26_col5, #T_0f03f_row26_col19 {
#   background-color: #e4ca8c;
#   color: #000000;
# }
# #T_0f03f_row0_col9, #T_0f03f_row2_col29, #T_0f03f_row3_col16, #T_0f03f_row4_col15, #T_0f03f_row5_col22, #T_0f03f_row8_col22, #T_0f03f_row9_col11, #T_0f03f_row18_col22 {
#   background-color: #c08430;
#   color: #f1f1f1;
# }
# #T_0f03f_row0_col10, #T_0f03f_row10_col11, #T_0f03f_row15_col16, #T_0f03f_row18_col3, #T_0f03f_row27_col5 {
#   background-color: #dcbc75;
#   color: #000000;
# }
# #T_0f03f_row0_col11, #T_0f03f_row1_col16, #T_0f03f_row2_col4, #T_0f03f_row2_col13, #T_0f03f_row2_col14, #T_0f03f_row2_col17, #T_0f03f_row2_col20, #T_0f03f_row2_col24, #T_0f03f_row5_col25, #T_0f03f_row7_col8, #T_0f03f_row7_col9, #T_0f03f_row8_col7, #T_0f03f_row17_col2, #T_0f03f_row19_col3, #T_0f03f_row19_col5, #T_0f03f_row19_col6, #T_0f03f_row19_col10, #T_0f03f_row19_col11, #T_0f03f_row19_col12, #T_0f03f_row19_col15, #T_0f03f_row19_col21, #T_0f03f_row19_col22, #T_0f03f_row19_col23, #T_0f03f_row19_col26, #T_0f03f_row19_col27, #T_0f03f_row19_col28, #T_0f03f_row19_col29, #T_0f03f_row20_col18, #T_0f03f_row22_col0, #T_0f03f_row22_col1, #T_0f03f_row22_col19 {
#   background-color: #543005;
#   color: #f1f1f1;
# }
# #T_0f03f_row0_col12, #T_0f03f_row1_col21, #T_0f03f_row9_col2, #T_0f03f_row18_col1, #T_0f03f_row21_col19 {
#   background-color: #a16518;
#   color: #f1f1f1;
# }
# #T_0f03f_row0_col13, #T_0f03f_row6_col21, #T_0f03f_row13_col25, #T_0f03f_row17_col20 {
#   background-color: #d9b76f;
#   color: #000000;
# }
# #T_0f03f_row0_col14, #T_0f03f_row7_col29, #T_0f03f_row11_col2, #T_0f03f_row25_col5 {
#   background-color: #874e0a;
#   color: #f1f1f1;
# }
# #T_0f03f_row0_col15, #T_0f03f_row2_col1, #T_0f03f_row3_col1, #T_0f03f_row7_col22, #T_0f03f_row9_col20, #T_0f03f_row23_col22 {
#   background-color: #cd9d50;
#   color: #f1f1f1;
# }
# #T_0f03f_row0_col16, #T_0f03f_row2_col3, #T_0f03f_row27_col11 {
#   background-color: #824b09;
#   color: #f1f1f1;
# }
# #T_0f03f_row0_col17, #T_0f03f_row22_col2 {
#   background-color: #663a07;
#   color: #f1f1f1;
# }
# #T_0f03f_row0_col18, #T_0f03f_row16_col10, #T_0f03f_row25_col27, #T_0f03f_row28_col16 {
#   background-color: #c89343;
#   color: #f1f1f1;
# }
# #T_0f03f_row0_col19, #T_0f03f_row13_col20, #T_0f03f_row26_col24 {
#   background-color: #98d7cd;
#   color: #000000;
# }
# #T_0f03f_row0_col20, #T_0f03f_row6_col22, #T_0f03f_row7_col2, #T_0f03f_row7_col25 {
#   background-color: #b77928;
#   color: #f1f1f1;
# }
# #T_0f03f_row0_col21, #T_0f03f_row1_col18, #T_0f03f_row13_col17 {
#   background-color: #93580f;
#   color: #f1f1f1;
# }
# #T_0f03f_row0_col22, #T_0f03f_row2_col22, #T_0f03f_row18_col5, #T_0f03f_row19_col13 {
#   background-color: #7e4909;
#   color: #f1f1f1;
# }
# #T_0f03f_row0_col23, #T_0f03f_row5_col8, #T_0f03f_row7_col4, #T_0f03f_row16_col9, #T_0f03f_row16_col28, #T_0f03f_row25_col20, #T_0f03f_row28_col21 {
#   background-color: #e2c787;
#   color: #000000;
# }
# #T_0f03f_row0_col25, #T_0f03f_row17_col27 {
#   background-color: #633906;
#   color: #f1f1f1;
# }
# #T_0f03f_row0_col26, #T_0f03f_row4_col10, #T_0f03f_row8_col25, #T_0f03f_row9_col15, #T_0f03f_row12_col19, #T_0f03f_row25_col23 {
#   background-color: #f2e2b8;
#   color: #000000;
# }
# #T_0f03f_row0_col27, #T_0f03f_row11_col9, #T_0f03f_row18_col27 {
#   background-color: #e7cf94;
#   color: #000000;
# }
# #T_0f03f_row0_col28, #T_0f03f_row1_col3, #T_0f03f_row5_col14, #T_0f03f_row7_col20, #T_0f03f_row20_col0, #T_0f03f_row23_col20, #T_0f03f_row25_col11 {
#   background-color: #e9d39d;
#   color: #000000;
# }
# #T_0f03f_row0_col29, #T_0f03f_row2_col11, #T_0f03f_row11_col1 {
#   background-color: #5f3606;
#   color: #f1f1f1;
# }
# #T_0f03f_row1_col0 {
#   background-color: #015d54;
#   color: #f1f1f1;
# }
# #T_0f03f_row1_col2, #T_0f03f_row22_col5, #T_0f03f_row22_col18, #T_0f03f_row26_col11, #T_0f03f_row27_col21 {
#   background-color: #c58e3d;
#   color: #f1f1f1;
# }
# #T_0f03f_row1_col4, #T_0f03f_row7_col5, #T_0f03f_row23_col11, #T_0f03f_row29_col7 {
#   background-color: #edd9a8;
#   color: #000000;
# }
# #T_0f03f_row1_col5, #T_0f03f_row8_col23 {
#   background-color: #21847c;
#   color: #f1f1f1;
# }
# #T_0f03f_row1_col6, #T_0f03f_row7_col12, #T_0f03f_row9_col22, #T_0f03f_row18_col2, #T_0f03f_row20_col16, #T_0f03f_row26_col7 {
#   background-color: #b57826;
#   color: #f1f1f1;
# }
# #T_0f03f_row1_col7, #T_0f03f_row8_col4, #T_0f03f_row17_col25, #T_0f03f_row18_col19, #T_0f03f_row21_col25 {
#   background-color: #87d0c5;
#   color: #000000;
# }
# #T_0f03f_row1_col8, #T_0f03f_row5_col15, #T_0f03f_row6_col16, #T_0f03f_row14_col21, #T_0f03f_row22_col23, #T_0f03f_row25_col21, #T_0f03f_row26_col15 {
#   background-color: #e8d097;
#   color: #000000;
# }
# #T_0f03f_row1_col9, #T_0f03f_row1_col28, #T_0f03f_row9_col0, #T_0f03f_row9_col8, #T_0f03f_row12_col22, #T_0f03f_row28_col12 {
#   background-color: #f2f4f4;
#   color: #000000;
# }
# #T_0f03f_row1_col10, #T_0f03f_row6_col13, #T_0f03f_row10_col19, #T_0f03f_row12_col18, #T_0f03f_row14_col25, #T_0f03f_row29_col24 {
#   background-color: #def0ed;
#   color: #000000;
# }
# #T_0f03f_row1_col11, #T_0f03f_row1_col25, #T_0f03f_row21_col9 {
#   background-color: #5d3506;
#   color: #f1f1f1;
# }
# #T_0f03f_row1_col12, #T_0f03f_row2_col12, #T_0f03f_row4_col16, #T_0f03f_row4_col17, #T_0f03f_row9_col16, #T_0f03f_row27_col25 {
#   background-color: #a76a1d;
#   color: #f1f1f1;
# }
# #T_0f03f_row1_col13, #T_0f03f_row5_col9, #T_0f03f_row5_col28, #T_0f03f_row7_col13, #T_0f03f_row9_col13, #T_0f03f_row13_col18, #T_0f03f_row17_col1, #T_0f03f_row20_col23 {
#   background-color: #d6af65;
#   color: #000000;
# }
# #T_0f03f_row1_col15, #T_0f03f_row11_col19, #T_0f03f_row13_col6, #T_0f03f_row14_col11, #T_0f03f_row24_col18, #T_0f03f_row27_col6 {
#   background-color: #f0deb0;
#   color: #000000;
# }
# #T_0f03f_row1_col17, #T_0f03f_row20_col9 {
#   background-color: #8f540c;
#   color: #f1f1f1;
# }
# #T_0f03f_row1_col19, #T_0f03f_row15_col4, #T_0f03f_row17_col28, #T_0f03f_row24_col26 {
#   background-color: #ceece8;
#   color: #000000;
# }
# #T_0f03f_row1_col20, #T_0f03f_row4_col27, #T_0f03f_row5_col3, #T_0f03f_row21_col16 {
#   background-color: #e0c481;
#   color: #000000;
# }
# #T_0f03f_row1_col22, #T_0f03f_row3_col2, #T_0f03f_row18_col20 {
#   background-color: #91560d;
#   color: #f1f1f1;
# }

# %%
plt.matshow(cov);
