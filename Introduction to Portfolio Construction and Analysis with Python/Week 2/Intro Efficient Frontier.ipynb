# %% [markdown]
# # Efficient Frontier

# %%
import pandas as pd

industry_returns = pd.read_csv(
    "../data/ind30_m_vw_rets.csv", 
    index_col = 0, 
    header = 0, 
    parse_dates = True
)

industry_returns = industry_returns / 100
industry_returns.head()
# Out:
#          Food    Beer    Smoke   Games   Books   Hshld   Clths   Hlth   \
# 192607  0.0056 -0.0519  0.0129  0.0293  0.1097 -0.0048  0.0808  0.0177
# 192608  0.0259  0.2703  0.0650  0.0055  0.1001 -0.0358 -0.0251  0.0425
# 192609  0.0116  0.0402  0.0126  0.0658 -0.0099  0.0073 -0.0051  0.0069
# 192610 -0.0306 -0.0331  0.0106 -0.0476  0.0947 -0.0468  0.0012 -0.0057
# 192611  0.0635  0.0729  0.0455  0.0166 -0.0580 -0.0054  0.0187  0.0542
#
#          Chems   Txtls  ...   Telcm   Servs   BusEq   Paper   Trans   Whlsl  \
# 192607  0.0814  0.0039  ...  0.0083  0.0922  0.0206  0.0770  0.0193 -0.2379
# 192608  0.0550  0.0814  ...  0.0217  0.0202  0.0439 -0.0238  0.0488  0.0539
# 192609  0.0533  0.0231  ...  0.0241  0.0225  0.0019 -0.0554  0.0005 -0.0787
# 192610 -0.0476  0.0100  ... -0.0011 -0.0200 -0.0109 -0.0508 -0.0264 -0.1538
# 192611  0.0520  0.0311  ...  0.0163  0.0377  0.0364  0.0384  0.0160  0.0467
#
#          Rtail   Meals   Fin     Other
# 192607  0.0007  0.0187  0.0037  0.0520
# ...

# %%
industry_returns.index = pd.to_datetime(
    industry_returns.index, 
    format="%Y%m"
).to_period("M")


industry_returns.head()
# Out:
#           Food    Beer    Smoke   Games   Books   Hshld   Clths   Hlth   \
# 1926-07  0.0056 -0.0519  0.0129  0.0293  0.1097 -0.0048  0.0808  0.0177
# 1926-08  0.0259  0.2703  0.0650  0.0055  0.1001 -0.0358 -0.0251  0.0425
# 1926-09  0.0116  0.0402  0.0126  0.0658 -0.0099  0.0073 -0.0051  0.0069
# 1926-10 -0.0306 -0.0331  0.0106 -0.0476  0.0947 -0.0468  0.0012 -0.0057
# 1926-11  0.0635  0.0729  0.0455  0.0166 -0.0580 -0.0054  0.0187  0.0542
#
#           Chems   Txtls  ...   Telcm   Servs   BusEq   Paper   Trans   Whlsl  \
# 1926-07  0.0814  0.0039  ...  0.0083  0.0922  0.0206  0.0770  0.0193 -0.2379
# 1926-08  0.0550  0.0814  ...  0.0217  0.0202  0.0439 -0.0238  0.0488  0.0539
# 1926-09  0.0533  0.0231  ...  0.0241  0.0225  0.0019 -0.0554  0.0005 -0.0787
# 1926-10 -0.0476  0.0100  ... -0.0011 -0.0200 -0.0109 -0.0508 -0.0264 -0.1538
# 1926-11  0.0520  0.0311  ...  0.0163  0.0377  0.0364  0.0384  0.0160  0.0467
#
#           Rtail   Meals   Fin     Other
# ...

# %%
industry_returns.columns = industry_returns.columns.str.strip()
industry_returns.columns = industry_returns.columns.str.lower()
industry_returns.head(2)
# Out:
#            food    beer   smoke   games   books   hshld   clths    hlth  \
# 1926-07  0.0056 -0.0519  0.0129  0.0293  0.1097 -0.0048  0.0808  0.0177
# 1926-08  0.0259  0.2703  0.0650  0.0055  0.1001 -0.0358 -0.0251  0.0425
#
#           chems   txtls  ...   telcm   servs   buseq   paper   trans   whlsl  \
# 1926-07  0.0814  0.0039  ...  0.0083  0.0922  0.0206  0.0770  0.0193 -0.2379
# 1926-08  0.0550  0.0814  ...  0.0217  0.0202  0.0439 -0.0238  0.0488  0.0539
#
#           rtail   meals     fin   other
# 1926-07  0.0007  0.0187  0.0037  0.0520
# 1926-08 -0.0075 -0.0013  0.0446  0.0676
#
# [2 rows x 30 columns]

# %%
# %load_ext autoreload
# %autoreload 2
import stark
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
industry_returns = stark.get_ind_returns()
industry_returns.head(2)
# Out:
#            food    beer   smoke   games   books   hshld   clths    hlth  \
# 1926-07  0.0056 -0.0519  0.0129  0.0293  0.1097 -0.0048  0.0808  0.0177
# 1926-08  0.0259  0.2703  0.0650  0.0055  0.1001 -0.0358 -0.0251  0.0425
#
#           chems   txtls  ...   telcm   servs   buseq   paper   trans   whlsl  \
# 1926-07  0.0814  0.0039  ...  0.0083  0.0922  0.0206  0.0770  0.0193 -0.2379
# 1926-08  0.0550  0.0814  ...  0.0217  0.0202  0.0439 -0.0238  0.0488  0.0539
#
#           rtail   meals     fin   other
# 1926-07  0.0007  0.0187  0.0037  0.0520
# 1926-08 -0.0075 -0.0013  0.0446  0.0676
#
# [2 rows x 30 columns]

# %%
stark.calculate_drawdown(
    industry_returns["food"]
).drawdown.plot(
    figsize=(12, 6)
);

# %%
industry_list = ["food", "smoke", "coal", "beer", "fin"]
stark.calculate_var_gaussian(
    industry_returns[industry_list], 
    modified=True
)
# Out:
# food     0.061207
# smoke    0.080292
# coal     0.047359
# beer     0.033881
# fin      0.075199
# dtype: float64

# %%
stark.calculate_var_gaussian(
    industry_returns, 
    modified = True
).sort_values().tail()
# Out:
# carry    0.094527
# meals    0.098403
# buseq    0.099377
# games    0.100701
# mines    0.102782
# dtype: float64

# %%
stark.calculate_var_gaussian(
    industry_returns, 
    modified = True
).sort_values().head()
# Out:
# beer     0.033881
# coal     0.047359
# food     0.061207
# telcm    0.064719
# hshld    0.064886
# dtype: float64

# %%
stark.calculate_var_gaussian(
    industry_returns, 
    modified = True
).sort_values().plot.bar();

# %%
stark.calculate_sharpe_ratio(
    input_returns = industry_returns, 
    risk_free_rate = 0.03, 
    periods_per_year = 12, 
).sort_values().plot.bar(
    title="Industry Sharpe Ratios from 1926 to 2018", 
    color="Green"
);

# %%
stark.calculate_sharpe_ratio(
    input_returns = industry_returns.loc["2000":], 
    risk_free_rate = 0.03, 
    periods_per_year = 12, 
).sort_values().plot.bar(
    title="Industry Sharpe Ratios from 1926 to 2018", 
    color="goldenrod", 
    figsize=(12, 5)
);

# %%
annualized_returns_subset = stark.calculate_annualize_rets(
    industry_returns.loc["1995":"2000"], 
    periods_per_year = 12
)

# %%
annualized_returns_subset.sort_values().plot.bar()
# Out:
# <AxesSubplot:>

# %%
cov_mat_ind = industry_returns.loc["1995":"2000"].cov()
cov_mat_ind.shape
# Out:
# (30, 30)

# %%
cov_mat_ind.style.background_gradient(cmap ="Blues")
# Out:
# <style type="text/css">
# #T_74de4_row0_col0, #T_74de4_row1_col1, #T_74de4_row2_col2, #T_74de4_row3_col3, #T_74de4_row4_col4, #T_74de4_row5_col5, #T_74de4_row6_col6, #T_74de4_row7_col7, #T_74de4_row8_col8, #T_74de4_row9_col9, #T_74de4_row10_col10, #T_74de4_row11_col11, #T_74de4_row12_col12, #T_74de4_row13_col13, #T_74de4_row14_col14, #T_74de4_row15_col15, #T_74de4_row16_col16, #T_74de4_row17_col17, #T_74de4_row18_col18, #T_74de4_row19_col19, #T_74de4_row20_col20, #T_74de4_row21_col21, #T_74de4_row22_col22, #T_74de4_row23_col23, #T_74de4_row24_col24, #T_74de4_row25_col25, #T_74de4_row26_col26, #T_74de4_row27_col27, #T_74de4_row28_col28, #T_74de4_row29_col29 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_74de4_row0_col1, #T_74de4_row0_col24, #T_74de4_row2_col25, #T_74de4_row4_col8, #T_74de4_row5_col7, #T_74de4_row8_col6, #T_74de4_row13_col8, #T_74de4_row14_col5 {
#   background-color: #81badb;
#   color: #000000;
# }
# ...
